# %% [markdown]
# # Testing the logistic regression using various real-world data sets.
#
# ## Author: Bojian Xu, bojianxu@ewu.edu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logistic_regression as logic
import sys
sys.path.append('..')
from code_misc.utils import MyUtils

# %%
data_set = 'ionosphere'

print(data_set+'/'+'hello')
# Out:
# ionosphere/hello

# %%
# READ in data
df_X_train = pd.read_csv(data_set+'/'+'X_train.csv', header=None)
df_y_train = pd.read_csv(data_set+'/'+'y_train.csv', header=None)
df_X_test = pd.read_csv(data_set+'/'+'X_test.csv', header=None)
df_y_test = pd.read_csv(data_set+'/'+'y_test.csv', header=None)

# save in numpy arrays
X_train = MyUtils.normalize_0_1(df_X_train.to_numpy())
y_train = MyUtils.normalize_0_1(df_y_train.to_numpy())
X_test = MyUtils.normalize_0_1(df_X_test.to_numpy())
y_test = MyUtils.normalize_0_1(df_y_test.to_numpy())

# get training set size
n_train = X_train.shape[0]

# normalize all features to [0,1] or [-1,1]
if data_set == 'ionosphere':
    X_all = MyUtils.normalize_neg1_pos1(np.concatenate((X_train, X_test), axis=0))


X_train = X_all[:n_train]
X_test = X_all[n_train:]

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
#print(y_test)
# Out:
# (280, 34)
# (280, 1)
# (71, 34)
# (71, 1)

# %%
#print(y_train[-10:])

# %%
# build the model
log = logic.LogisticRegression()

# %%
# train the model
log.fit(X_train, y_train, lam = 0.1, eta = 0.01, iterations = 10000, SGD = False, mini_batch_size = 20, degree = 3)
#log.fit(X_train, y_train, lam = 0, eta = 0.1, iterations = 50000, SGD = True, mini_batch_size = 20, degree = 3)
print(log.w)
# Out:
# [[ 0.42981108]
#  [ 0.42981108]
#  [ 0.        ]
#  ...
#  [-0.00114915]
#  [-0.00142066]
#  [-0.00307851]]

# %%
print('misclassfied percentage from training: ', log.error(X_train, y_train)/X_train.shape[0])
print('misclassfied percentage from validation: ', log.error(X_test, y_test)/X_test.shape[0])
# Out:
# misclassfied percentage from training:  0.31785714285714284
# misclassfied percentage from validation:  0.36619718309859156

# %%
preds = log.predict(X_test)
print(preds)
# Out:
# [[1.        ]
#  [0.9999881 ]
#  [0.90501521]
#  [0.98174357]
#  [0.99995874]
#  [1.        ]
#  [0.99999978]
#  [0.99993037]
#  [0.9060508 ]
#  [0.93344188]
#  [0.99999109]
#  [1.        ]
#  [0.9770123 ]
#  [1.        ]
#  [1.        ]
#  [0.41116895]
#  [0.99999517]
#  [0.9017764 ]
#  [0.99877627]
#  [0.99976421]
#  [0.84948193]
#  [0.61436632]
#  [0.99999003]
#  [0.99999997]
#  [0.99998798]
#  [0.99986372]
#  [0.99989326]
#  [0.99997583]
#  [0.99999766]
#  [0.99999871]
#  [0.72463747]
#  [0.99997569]
#  [0.99839502]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.99999996]
#  [1.        ]
#  [0.84263677]
#  [0.99999998]
#  [0.83965089]
#  [1.        ]
#  [0.92076586]
#  [0.99979136]
#  [0.9999712 ]
#  [0.99709958]
#  [0.99998689]
#  [0.99998258]
#  [0.99996524]
#  [0.85482856]
#  [0.99997705]
#  [0.99998246]
#  [0.98396321]
#  [0.99999887]
#  [0.9998857 ]
#  [0.99999941]
#  [0.96669597]
#  [0.99929008]
#  [0.99999546]
#  [0.9999999 ]
#  [0.99989333]
#  [1.        ]
#  [0.99786212]
#  [0.99998655]
#  [0.51573976]
#  [0.99999894]
#  [1.        ]
#  [0.99984217]
#  [1.        ]
#  [0.98479323]
#  [0.97763361]]

# %%
m_count = 0
count = 0
for i in range(y_test.shape[0]):
    print('test sample ', i)
    if np.sign(preds[i]-0.5) != y_test[i]:
        print('misclassified!!')
        m_count += 1
    print('predicted probablity of being +1 is: ', preds[i])
    count += 1
    print('label is', y_test[i])
    print('\n')
    
print("\n", m_count, "\n", count)
# Out:
# test sample  0
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  1
# predicted probablity of being +1 is:  [0.9999881]
# label is [1.]
#
#
# test sample  2
# misclassified!!
# predicted probablity of being +1 is:  [0.90501521]
# label is [0.]
#
#
# test sample  3
# predicted probablity of being +1 is:  [0.98174357]
# label is [1.]
#
#
# test sample  4
# predicted probablity of being +1 is:  [0.99995874]
# label is [1.]
#
#
# test sample  5
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  6
# predicted probablity of being +1 is:  [0.99999978]
# label is [1.]
#
#
# test sample  7
# predicted probablity of being +1 is:  [0.99993037]
# label is [1.]
#
#
# test sample  8
# misclassified!!
# predicted probablity of being +1 is:  [0.9060508]
# label is [0.]
#
#
# test sample  9
# misclassified!!
# predicted probablity of being +1 is:  [0.93344188]
# label is [0.]
#
#
# test sample  10
# predicted probablity of being +1 is:  [0.99999109]
# label is [1.]
#
#
# test sample  11
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  12
# misclassified!!
# predicted probablity of being +1 is:  [0.9770123]
# label is [0.]
#
#
# test sample  13
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  14
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  15
# misclassified!!
# predicted probablity of being +1 is:  [0.41116895]
# label is [0.]
#
#
# test sample  16
# predicted probablity of being +1 is:  [0.99999517]
# label is [1.]
#
#
# test sample  17
# misclassified!!
# predicted probablity of being +1 is:  [0.9017764]
# label is [0.]
#
#
# test sample  18
# predicted probablity of being +1 is:  [0.99877627]
# label is [1.]
#
#
# test sample  19
# predicted probablity of being +1 is:  [0.99976421]
# label is [1.]
#
#
# test sample  20
# misclassified!!
# predicted probablity of being +1 is:  [0.84948193]
# label is [0.]
#
#
# test sample  21
# misclassified!!
# predicted probablity of being +1 is:  [0.61436632]
# label is [0.]
#
#
# test sample  22
# predicted probablity of being +1 is:  [0.99999003]
# label is [1.]
#
#
# test sample  23
# predicted probablity of being +1 is:  [0.99999997]
# label is [1.]
#
#
# test sample  24
# predicted probablity of being +1 is:  [0.99998798]
# label is [1.]
#
#
# test sample  25
# predicted probablity of being +1 is:  [0.99986372]
# label is [1.]
#
#
# test sample  26
# predicted probablity of being +1 is:  [0.99989326]
# label is [1.]
#
#
# test sample  27
# predicted probablity of being +1 is:  [0.99997583]
# label is [1.]
#
#
# test sample  28
# misclassified!!
# predicted probablity of being +1 is:  [0.99999766]
# label is [0.]
#
#
# test sample  29
# predicted probablity of being +1 is:  [0.99999871]
# label is [1.]
#
#
# test sample  30
# misclassified!!
# predicted probablity of being +1 is:  [0.72463747]
# label is [0.]
#
#
# test sample  31
# misclassified!!
# predicted probablity of being +1 is:  [0.99997569]
# label is [0.]
#
#
# test sample  32
# misclassified!!
# predicted probablity of being +1 is:  [0.99839502]
# label is [0.]
#
#
# test sample  33
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  34
# misclassified!!
# predicted probablity of being +1 is:  [1.]
# label is [0.]
#
#
# test sample  35
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  36
# predicted probablity of being +1 is:  [0.99999996]
# label is [1.]
#
#
# test sample  37
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  38
# misclassified!!
# predicted probablity of being +1 is:  [0.84263677]
# label is [0.]
#
#
# test sample  39
# predicted probablity of being +1 is:  [0.99999998]
# label is [1.]
#
#
# test sample  40
# misclassified!!
# predicted probablity of being +1 is:  [0.83965089]
# label is [0.]
#
#
# test sample  41
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  42
# misclassified!!
# predicted probablity of being +1 is:  [0.92076586]
# label is [0.]
#
#
# test sample  43
# predicted probablity of being +1 is:  [0.99979136]
# label is [1.]
#
#
# test sample  44
# predicted probablity of being +1 is:  [0.9999712]
# label is [1.]
#
#
# test sample  45
# predicted probablity of being +1 is:  [0.99709958]
# label is [1.]
#
#
# test sample  46
# misclassified!!
# predicted probablity of being +1 is:  [0.99998689]
# label is [0.]
#
#
# test sample  47
# misclassified!!
# predicted probablity of being +1 is:  [0.99998258]
# label is [0.]
#
#
# test sample  48
# predicted probablity of being +1 is:  [0.99996524]
# label is [1.]
#
#
# test sample  49
# misclassified!!
# predicted probablity of being +1 is:  [0.85482856]
# label is [0.]
#
#
# test sample  50
# predicted probablity of being +1 is:  [0.99997705]
# label is [1.]
#
#
# test sample  51
# predicted probablity of being +1 is:  [0.99998246]
# label is [1.]
#
#
# test sample  52
# misclassified!!
# predicted probablity of being +1 is:  [0.98396321]
# label is [0.]
#
#
# test sample  53
# predicted probablity of being +1 is:  [0.99999887]
# label is [1.]
#
#
# test sample  54
# predicted probablity of being +1 is:  [0.9998857]
# label is [1.]
#
#
# test sample  55
# misclassified!!
# predicted probablity of being +1 is:  [0.99999941]
# label is [0.]
#
#
# test sample  56
# predicted probablity of being +1 is:  [0.96669597]
# label is [1.]
#
#
# test sample  57
# predicted probablity of being +1 is:  [0.99929008]
# label is [1.]
#
#
# test sample  58
# predicted probablity of being +1 is:  [0.99999546]
# label is [1.]
#
#
# test sample  59
# predicted probablity of being +1 is:  [0.9999999]
# label is [1.]
#
#
# test sample  60
# predicted probablity of being +1 is:  [0.99989333]
# label is [1.]
#
#
# test sample  61
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  62
# misclassified!!
# predicted probablity of being +1 is:  [0.99786212]
# label is [0.]
#
#
# test sample  63
# misclassified!!
# predicted probablity of being +1 is:  [0.99998655]
# label is [0.]
#
#
# test sample  64
# misclassified!!
# predicted probablity of being +1 is:  [0.51573976]
# label is [0.]
#
#
# test sample  65
# predicted probablity of being +1 is:  [0.99999894]
# label is [1.]
#
#
# test sample  66
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  67
# misclassified!!
# predicted probablity of being +1 is:  [0.99984217]
# label is [0.]
#
#
# test sample  68
# predicted probablity of being +1 is:  [1.]
# label is [1.]
#
#
# test sample  69
# misclassified!!
# predicted probablity of being +1 is:  [0.98479323]
# label is [0.]
#
#
# test sample  70
# misclassified!!
# predicted probablity of being +1 is:  [0.97763361]
# label is [0.]
#
#
#
#  27
#  71
